# %%
from bs4 import BeautifulSoup
import requests
import time
from random import randint

def scrape_sports_summaries(s):
    time.sleep(randint(0, 2))  # relax and don't let them know
    r = requests.get("https://www.stuff.co.nz/"+s)
    print(r.status_code)  # Print the status code
    content = r.text
    news_summaries = []
    soup = BeautifulSoup(content, "html.parser")
    st_divs = soup.findAll("div", {"class": "big-headline-top-stories section"})

    # print(st_divs)
    for st_div in st_divs:
        news_summaries.append(st_div.text)
    return news_summaries

def scrape_travel_summaries(s):
    time.sleep(randint(0, 2))  # relax and don't let them know
    r = requests.get("https://www.stuff.co.nz/"+s)
    print(r.status_code)  # Print the status code
    content = r.text
    news_summaries = []
    soup = BeautifulSoup(content, "html.parser")
    st_divs = soup.findAll("div", {"class": "content no-intro"})
    # print(st_divs)
    for st_div in st_divs:
        news_summaries.append(st_div.text)
    return news_summaries

# %%
l = scrape_sports_summaries("sport")
for n in l:
    print(n)
# Out:
# 200
#
#
#
#
#
#
#         Beauden Barrett is not in “big boxing match” for the No 10 jersey, says ABs coach
#
#
#
#
#
#
#
#
#
#
# 3:46 PM
#
#                     Richie Mo'unga given "the points" at this stage of the intriguing ABs No 10 battle, which gets him the nod to start in Hamilton.
#
#
#
#
#
#
#
#
#
#         Ardie Savea to start at No 7 for All Blacks against Fiji
#
#
#
#
#
#
#
#
#
#
#
#                     Ardie Savea is back at openside flanker as Ian Foster names an experienced side for second test in Hamilton.
#
#
#
#
#
#
#
#         Battling British and Irish Lions suffer first tour loss
#
#
#
#
#
#
#
#
#
#
#
#                     A powerful team packed with 11 members of the World Cup-winning Springboks proves too strong for the tourists, despite an improved second half display.
#
#
#
#
#
#
#
#
#         Kendra Cocksedge's decision not to retire after World Cup postponement paying off
#
#
#
#
#
#
#
#
#
#
#
#                     Black Ferns star took the World Cup being pushed back more than a year worse than she thought, but an extended break has her back on track.
#
#
#
#
#
#
#
#
#         New Zealand's oldest Olympian passes away
#
#
#
#
#
#
#
#
#
#
# 4:19 PM
#
#                     Ngaire Lane held multiple national swimming records during the 1940s, and went on to represent New Zealand in backstroke at the 1948 London Olympics.

# %%
l = scrape_travel_summaries("travel")
for n in l:
    print(n)
# Out:
# 200
